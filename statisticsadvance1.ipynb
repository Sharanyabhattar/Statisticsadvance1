# %% [markdown]
# 1. What is a random variable in probability theory?
# -  A random variable in probability theory is a variable that represents the outcome of a random phenomenon. It assigns a numerical value to each possible outcome of a random experiment.
#
# 2. What are the types of random variables?
# - Random variables are classified mainly into two broad types:
#
# 1. Discrete Random Variables
# Definition: A random variable that can take on a countable number of distinct values.
#
# Examples:
#
# Number of heads in 10 coin tosses.
#
# Number of students present in a class.
#
# Characteristics:
#
# Values can be listed (finite or countably infinite).
#
# Often associated with probability mass functions (PMF).
#
# 2. Continuous Random Variables
# Definition: A random variable that can take on an infinite number of possible values within a given range or interval.
#
# Examples:
#
# Height of students.
#
# Time taken to run a marathon.
#
# Characteristics:
#
# Values are uncountable and can be measured.
#
# Described by probability density functions (PDF).
#
# 3. What is the difference between discrete and continuous distributions?
# -  The difference between discrete and continuous distributions lies in the type of values the random variable can take and how probabilities are assigned.
#
# 1. Discrete Probability Distributions
# Definition: Deals with discrete random variables (countable values).
#
# Probabilities are assigned to exact values.
#
# Represented by the Probability Mass Function (PMF).
#
# The sum of all probabilities equals 1.
#
# Examples:
# Binomial Distribution (number of successes in trials)
#
# Poisson Distribution (number of events in a time period)
#
# Geometric Distribution
#
# 2. Continuous Probability Distributions
# Definition: Deals with continuous random variables (uncountable values in an interval).
#
# Probabilities are assigned over intervals, not exact values.
#
# Represented by the Probability Density Function (PDF).
#
# The area under the curve of the PDF over an interval represents probability.
#
# The total area under the PDF curve equals 1.
#
# Examples:
# Normal Distribution (bell-shaped curve)
#
# Exponential Distribution (time between events)
#
# Uniform Distribution (constant probability over an interval)
#
# 4. What are probability distribution functions (PDF)
# - A Probability Distribution Function (PDF) is a function that describes the likelihood of a continuous random variable taking on a particular value. It shows how probabilities are distributed over the values of the variable.
#
#  For continuous random variables, the probability at an exact point is zero. Instead, we calculate the probability over an interval.
#
# Key Properties of a PDF:
# Non-negative:
#
# 𝑓
# (
# 𝑥
# )
# ≥
# 0
# for all values of
# 𝑥
# f(x)≥0for all values of x
# Total Area = 1:
# The total area under the curve of the PDF across all possible values equals 1.
#
# ∫
# −
# ∞
# ∞
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# =
# 1
# ∫
# −∞
# ∞
# ​
#  f(x)dx=1
# Probability in an Interval:
# The probability that a random variable X lies between a and b is given by:
#
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
# Visual Idea:
# The PDF is a smooth curve.
#
# The height of the curve at point x represents the density, not probability.
#
# Area under the curve between two points gives actual probability.
#
# 5.  How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# - cumulative distribution functions(CDF)
#  Definition:Describes the probability that a random variable is less than or equal to a certain value.
#  Notation:  F(x)
#  Meaning: Actual cumulative probability up to point
# 𝑥
# x.
# Probability between two points:Difference of CDF values at two points:
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# 𝐹
# (
# 𝑏
# )
# −
# 𝐹
# (
# 𝑎
# )
# P(a≤X≤b)=F(b)−F(a)
# Range of values:Always between 0 and 1.
# Graph Shape:Always a non-decreasing S-shaped or step-like curve.
#
# Probability Density Function (PDF)
# Definition:Describes the likelihood (density) of a continuous random variable taking a specific value.
# Notation:f(x)
# meaning:Height of the curve at a point (not a probability itself).
# Probability Between Two Points:	Calculated as the area under the PDF curve between two points:
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
#  Range of Values:	Can be greater than 1 (height of curve), but area under entire curve equals 1.
# Graph Shape:	Smooth curve showing density (e.g., bell curve for normal distribution).
#
# 6. What is a discrete uniform distribution?
# - A random variable X has a discrete uniform distribution if it takes on finite, countable values, and each value has the same probability.
#
# For possible values
# 𝑥
# 1
# ,
# 𝑥
# 2
# ,
# …
# ,
# 𝑥
# 𝑛
# x
# 1
# ​
#  ,x
# 2
# ​
#  ,…,x
# n
# ​
#  :
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# 𝑖
# )
# =
# 1
# 𝑛
# for all
# 𝑖
# =
# 1
# ,
# 2
# ,
# …
# ,
# 𝑛
# P(X=x
# i
# ​
#  )=
# n
# 1
# ​
#  for all i=1,2,…,n
# where
# 𝑛
# n is the total number of possible outcomes.
#
# 7. What are the key properties of a Bernoulli distribution?
# - key properties:
# . Random variable type:Discrete
# . Equal Probability:	All outcomes are equally likely
# . Probability Mass Function (PMF)
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# 𝑛
# P(X=x)=
# n
# 1
# ​
# . Mean (Expected Value)
# 𝐸
# [
# 𝑋
# ]
# =
# 𝑎
# +
# 𝑏
# 2
# E[X]=
# 2
# a+b
# ​
# . Variance
# 𝑉
# 𝑎
# 𝑟
# (
# 𝑋
# )
# =
# (
# 𝑏
# −
# 𝑎
# +
# 1
# )
# 2
# −
# 1
# 12
# Var(X)=
# 12
# (b−a+1)
# 2
#  −1
# ​
# where
# 𝑎
# a is the smallest value and
# 𝑏
# b is the largest value.
#
# 8. What is the binomial distribution, and how is it used in probability?
# - The Binomial distribution models the number of successes in a fixed number of independent trials, where:
#
# Each trial has two possible outcomes (Success or Failure).
#
# The probability of success (p) is the same in every trial.
# Predicting counts of successes in repeated independent trials.
#
# Quality control: Probability of getting a certain number of defective items.
#
# Medical trials: Probability of certain number of patients responding to treatment.
#
# Elections: Modeling yes/no responses in polls.
#
# When to Use the Binomial Distribution:
# . Fixed number of trials (n).
# . Each trial is independent.
# . Only two outcomes (Success or Failure).
# . Constant probability of success (p).
#
#
# 9. What is the Poisson distribution and where is it applied?
# -  The Poisson distribution is a discrete probability distribution that models the number of times an event occurs in a fixed interval of time or space, when events occur randomly and independently at a constant average rate.
# Common Applications:
# Field
# . Telecommunications
# . Traffic Engineering
# . Epidemiology
# . Quality Control
# .  Astronomy
#
# 10. What is a continuous uniform distribution?
# - A Continuous Uniform Distribution models a random variable that has an equal chance of taking any value within a given interval.
#
# Every number in the interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] is equally likely.
#
# It's called "uniform" because the probability density is constant.
#
#
# 11. What are the characteristics of a normal distribution?
# - The Normal Distribution is one of the most important distributions in probability and statistics. Here are its key characteristics:
#
# Characteristics of a Normal Distribution
# Feature	:
# Shape:	Bell-shaped and symmetric curve.
# Symmetry:	Perfectly symmetric about the mean (μ).
# Mean = Median = Mode:	All three are equal and located at the center.
# Spread Controlled by Standard Deviation (σ):	The curve's width is determined by σ. A larger σ makes the curve wider and flatter; a smaller σ makes it narrower and taller.
# Probability Density Function (PDF):
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝜎
# 2
# 𝜋
# 𝑒
# −
# (
# 𝑥
# −
# 𝜇
# )
# 2
# 2
# 𝜎
# 2
# f(x)=
# σ
# 2π
# ​
#
# 1
# ​
#  e
# −
# 2σ
# 2
#
# (x−μ)
# 2
#
# ​
#
#
# Total Area Under Curve = 1:	Represents total probability (100%).
# Empirical Rule (68-95-99.7 Rule):	- ~68% of data within 1σ of the mean.
# - ~95% within 2σ.
# - ~99.7% within 3σ.
# Tails extend to infinity:	The curve approaches but never touches the x-axis (asymptotic).
# No skewness:	Skewness = 0 (perfect symmetry).
# Kurtosis:	Mesokurtic (moderate peakness compared to other distributions).
#
# Visual Idea:
# Bell curve centered at μ.
#
# Spread determined by σ.
#
# The area under the curve represents probabilities.
# Applications:
# Heights, weights, IQ scores, test scores.
#
# Measurement errors.
#
# Many natural phenomena due to the Central Limit Theorem (CLT).
#
# Special Case: Standard Normal Distribution
# Mean
# 𝜇
# =
# 0
# μ=0
#
# Standard Deviation
# 𝜎
# =
# 1
# σ=1
#
# Random variable often denoted by
# 𝑍
# Z.
#
# 12. What is the standard normal distribution, and why is it important?
# - The Standard Normal Distribution is a special case of the normal distribution where:
#
# The mean (μ) = 0.
#
# The standard deviation (σ) = 1.
#
# It's often referred to as the Z-distribution, and the variable is denoted by
# 𝑍
# Z.
#
# Probability Density Function (PDF):
# 𝑓
# (
# 𝑧
# )
# =
# 1
# 2
# 𝜋
# 𝑒
# −
# 𝑧
# 2
# 2
# f(z)=
# 2π
# ​
#
# 1
# ​
#  e
# −
# 2
# z
# 2
#
# ​
#
#
# where
# 𝑧
# z is any real number.
#
# Key Properties:
# Feature	Value
# Mean (μ):	0
# Standard Deviation (σ):	1
# Symmetry:	Symmetric about 0
# Total Area Under Curve:	1
# 68-95-99.7 Rule applies:	Same as normal distribution
# importance:
#
# | Reason                                         | Explanation                                                                                           |
# | ---------------------------------------------- | ----------------------------------------------------------------------------------------------------- |
# | **Simplifies Calculations**                    | Probabilities for any normal distribution can be converted to the standard normal using **z-scores**. |
# | **Z-score formula**                            | $Z = \frac{X - \mu}{\sigma}$ Converts any normal distribution to standard normal.                     |
# | **Tables & Software Use**                      | Standard normal tables (Z-tables) provide probabilities for various z-values.                         |
# | **Basis of Hypothesis Testing**                | Many statistical tests (e.g., Z-test, confidence intervals) rely on the standard normal.              |
# | **Foundation for Central Limit Theorem (CLT)** | Sampling distributions of the mean approximate a standard normal as sample size increases.            |
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# - The Central Limit Theorem (CLT) states that:
#
# The sampling distribution of the sample mean (or sum) of a large number of independent, identically distributed (i.i.d.) random variables will approximate a normal distribution, regardless of the original distribution of the data, as the sample size becomes large.
# In Simple Terms:
# Even if the original data is not normally distributed, the distribution of the sample means will become approximately normal if the sample size is large enough.
#
# The larger the sample size, the better the approximation.
#
#  CLT Critical in Statistics
#
# . Foundation of Inferential Statistics:	CLT justifies using normal distribution for confidence intervals and hypothesis testing, even when data isn't normal.
# . Allows Approximation: Enables the use of z-scores and t-scores for analysis of sample means.
# . Predictable Behavior of Large Samples:	Provides a guarantee that with a large enough sample, statistical results will be reliable and interpretable.
# . Widely Used in Practice:Used in polling, quality control, medical studies, finance, etc.
# . Simplifies Complex Problems	:Complex data distributions become manageable through normal approximation.
#
# 14. How does the Central Limit Theorem relate to the normal distribution?
# - Relationship Between CLT and the Normal Distribution
#  1. CLT Explains Why Normal Distribution Appears Frequently
# The normal distribution shows up in many natural and real-world phenomena.
#
# The CLT explains this: When we take averages (or sums) of many independent random variables, the result tends to follow a normal distribution, even if the original data is not normal.
#
#  2. Sampling Distributions Approximate Normality
# For any population (any shape: skewed, uniform, etc.), if we take many random samples and compute their means, the distribution of those sample means becomes approximately normal.
#
# This happens as the sample size (n) increases.
#
#  3. Standard Normal Distribution (Z-scores)
# Thanks to CLT, we can standardize the sampling distribution of the mean using:
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# This Z-score follows a standard normal distribution (mean 0, standard deviation 1), enabling us to use normal tables for probability calculations.
#
#  4. Key Point: Approximation Improves with Larger n
# The larger the sample size:
#
# The closer the sampling distribution of the mean gets to normal.
#
# The smaller the standard error (
# 𝜎
# /
# 𝑛
# σ/
# n
# ​
#  ).
#
# More reliable inference using normal distribution formulas.
#
# Visual Intuition:
# Even if the population is skewed or bimodal:
#
# The distribution of sample means becomes bell-shaped and symmetric due to the CLT.
#
# Hence, the normal distribution is used for inference.
#
# 15. What is the application of Z statistics in hypothesis testing?
# - A Z-statistic (or Z-score) measures how many standard deviations a data point (or sample statistic) is from the population mean.
#
# Formula for sample mean testing:
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 0
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# 0
# ​
#
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean
#
# 𝜇
# 0
# μ
# 0
# ​
#   = population mean under the null hypothesis
#
# 𝜎
# σ = population standard deviation
#
# 𝑛
# n = sample size
#
# Application of Z-Statistics in Hypothesis Testing
# 1. Hypothesis Testing Framework:
# Step 1: Define hypotheses:
#
# Null Hypothesis (H₀): Assumes no effect or difference (
# 𝜇
# =
# 𝜇
# 0
# μ=μ
# 0
# ​
#  ).
#
# Alternative Hypothesis (H₁): Assumes an effect or difference (
# 𝜇
# ≠
# 𝜇
# 0
# μ
# 
# =μ
# 0
# ​
#   or
# 𝜇
# >
# 𝜇
# 0
# μ>μ
# 0
# ​
#   or
# 𝜇
# <
# 𝜇
# 0
# μ<μ
# 0
# ​
#  ).
#
# Step 2: Calculate the Z-statistic using sample data.
#
# Step 3: Compare the calculated Z-value with the critical Z-value from standard normal distribution (based on chosen significance level, α).
#
# Step 4: Make a decision:
#
# If
# ∣
# 𝑍
# ∣
# ∣Z∣ is greater than the critical Z-value → Reject H₀.
#
# Otherwise → Fail to reject H₀.
#
# 2. Common Applications:
# Use Case:
# Single sample mean test:	Testing if the average height of a sample differs from the known population mean.
# Proportion test:	Testing if the proportion of voters supporting a candidate is different from 50%.
# Large sample tests (n ≥ 30)	:Z-tests are preferred when sample sizes are large and population standard deviation is known.
#
#  3. One-Tailed vs Two-Tailed Tests:
# One-Tailed Test: Tests for deviation in one direction (greater than or less than).
#
# Two-Tailed Test: Tests for deviation in both directions (not equal).
#
#  4. Confidence Intervals:
# Z-statistics are also used to construct confidence intervals for population parameters when σ is known.
#
# When to Use Z-Test:
#  Large sample size (typically
# 𝑛
# ≥
# 30
# n≥30).
#  Population standard deviation (σ) is known.
#  Data is approximately normally distributed (or by CLT).
#
#
# 16. How do you calculate a Z-score, and what does it represent?
# - Z-score Formula
# For a single data point:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# Where:
#
# 𝑋
# X = observed value (data point)
#
# 𝜇
# μ = population mean
#
# 𝜎
# σ = population standard deviation
#
# For a sample mean (hypothesis testing):
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 0
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# 0
# ​
#
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean
#
# 𝜇
# 0
# μ
# 0
# ​
#   = population mean under null hypothesis
#
# 𝑛
# n = sample size
#
#  A Z-score Represent
# Z-score Value	Meaning
# Z = 0	Data point is exactly at the mean.
# Z > 0	Data point is above the mean.
# Z < 0	Data point is below the mean.
# Z = +1	1 standard deviation above the mean.
# Z = -2	2 standard deviations below the mean.
#
# Interpretation Example:
# If you get a Z-score of +2.0:
#
# The data point is 2 standard deviations above the mean.
#
# This corresponds to being in the upper 2.5% tail of a standard normal distribution.
#
#
# 17. What are point estimates and interval estimates in statistics?
# - Point Estimates
# A point estimate is a single value used as the best guess or estimate of an unknown population parameter (like the mean, proportion, variance).
#
# It comes directly from sample data.
#
# Examples:
# Sample mean
# 𝑋
# ˉ
# X
# ˉ
#   is a point estimate of the population mean
# 𝜇
# μ.
#
# Sample proportion
# 𝑝
# ^
# p
# ^
# ​
#   is a point estimate of the population proportion
# 𝑝
# p.
#
# Interval Estimates
# An interval estimate gives a range of values (an interval) within which the population parameter is expected to lie.
#
# It provides a measure of uncertainty around the point estimate.
#
# Often expressed as a confidence interval.
#
# Example:
# A 95% confidence interval for the population mean might be
# 𝑋
# ˉ
# ±
# 𝐸
# X
# ˉ
#  ±E, where
# 𝐸
# E is the margin of error.
#
# 18. What is the significance of confidence intervals in statistical analysis?
# - 1. Measure of Precision and Uncertainty
# A confidence interval doesn’t just give a single estimate—it shows a range of plausible values for the population parameter.
#
# This range reflects the uncertainty inherent in estimating from a sample rather than the whole population.
#
#  2. Provides More Information than Point Estimates
# Unlike a point estimate (which is just one number), a confidence interval tells us how reliable that estimate is.
#
# Narrow intervals mean more precise estimates; wide intervals mean less certainty.
#
#  3. Basis for Decision-Making
# Helps researchers decide if the parameter lies within a certain range.
#
# Useful for testing hypotheses and making inferences about populations.
#
#  4. Confidence Level Interpretation
# The confidence level (e.g., 95%) means:
#
# If we were to repeat the sampling many times, about 95% of those confidence intervals would contain the true population parameter.
#
# It quantifies how confident we are in the interval estimate.
#
#  5. Communication Tool
# Confidence intervals communicate both the estimate and the associated uncertainty to stakeholders.
#
# Helps avoid overconfidence in precise but uncertain estimates.
#
#  6. Identifies Statistical Significance
# If a confidence interval for a difference (e.g., between two means) does not include zero, it suggests a statistically significant difference at that confidence level.
#
# 19. What is the relationship between a Z-score and a confidence interval?
# - Relationship Between Z-score and Confidence Interval
#  1. Z-score Determines the Width of the Confidence Interval
# A confidence interval around a sample mean is typically calculated as:
#
# CI
# =
# 𝑋
# ˉ
# ±
# 𝑍
# 𝛼
# /
# 2
# ×
# 𝜎
# 𝑛
# CI=
# X
# ˉ
#  ±Z
# α/2
# ​
#  ×
# n
# ​
#
# σ
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean
#
# 𝜎
# σ = population standard deviation
#
# 𝑛
# n = sample size
#
# 𝑍
# 𝛼
# /
# 2
# Z
# α/2
# ​
#   = Z-score corresponding to the desired confidence level
#
#  2. What is
# 𝑍
# 𝛼
# /
# 2
# Z
# α/2
# ​
#  ?
# 𝑍
# 𝛼
# /
# 2
# Z
# α/2
# ​
#   is the critical value from the standard normal distribution that cuts off the tails of the distribution so that the middle area equals the confidence level.
#
#  3. Intuition
# A higher confidence level (e.g., 99%) means you want to be more certain the interval contains the parameter → larger Z-score → wider interval.
#
# A lower confidence level (e.g., 90%) means less certainty → smaller Z-score → narrower interval.
#
#  4. Z-score Comes from the Standard Normal Distribution
# Because the sampling distribution of the mean is approximated by the normal distribution (by the CLT), the Z-score represents how far from the mean we go to capture a specified confidence level.
#
# 20. How are Z-scores used to compare different distributions?
# - To Compare different distributions
# Calculate the Z-score for each value:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# Compare the Z-scores:
#
# A higher positive Z-score means the value is further above its mean.
#
# A lower (more negative) Z-score means the value is further below its mean.
#
# The magnitude of Z-score shows how extreme or typical the value is.
#
#   Example:
# Student A scores 85 on a test where the class mean is 70 with SD 10.
#
# 𝑍
# 𝐴
# =
# 85
# −
# 70
# 10
# =
# 1.5
# Z
# A
# ​
#  =
# 10
# 85−70
# ​
#  =1.5
# Student B scores 45 on another test where the mean is 40 with SD 3.
#
# 𝑍
# 𝐵
# =
# 45
# −
# 40
# 3
# =
# 1.67
# Z
# B
# ​
#  =
# 3
# 45−40
# ​
#  =1.67
# Even though Student A scored higher raw (85 vs 45), Student B's Z-score is higher → Student B performed better relative to their class.
#
# 21. What are the assumptions for applying the Central Limit Theorem?
# - Assumptions for the Central Limit Theorem
# 1. Independence of Observations
# The data points (random variables) must be independent of each other.
#
# This usually means that the samples are drawn randomly and one observation does not influence another.
#
# 2. Identically Distributed
# The random variables should be identically distributed (i.i.d.): they come from the same probability distribution.
#
# Although some generalizations exist, the classic CLT assumes this condition.
#
# 3. Sample Size is Large Enough
# The sample size
# 𝑛
# n should be sufficiently large.
#
# A common rule of thumb:
# 𝑛
# ≥
# 30
# n≥30 is often considered large enough for CLT to hold well.
#
# For highly skewed or heavy-tailed distributions, even larger samples may be needed.
#
# 4. Finite Variance
# The population distribution must have a finite variance
# 𝜎
# 2
# σ
# 2
#  .
#
# If the variance is infinite, the CLT may not apply.
#
# 22. What is the concept of expected value in a probability distribution?
# - The expected value is the theoretical average outcome of a random process, calculated by weighting each possible value by its probability. It reflects the center of gravity of a probability distribution.
#
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# - Relationship Between Probability Distribution & Expected Value
#  1. Probability Distribution Defines the Likelihood of Outcomes
# A probability distribution shows all possible values a random variable can take and their corresponding probabilities.
#
# It can be:
#
# Discrete (e.g., dice rolls, coin tosses)
#
# Continuous (e.g., heights, weights)
#
#  2. Expected Value is the Weighted Average of the Distribution
# The expected value (mean) is calculated by weighting each outcome by its probability.
#
# It represents the long-run average or center of the distribution.
#
#  3. The Expected Value Depends Directly on the Distribution
# The shape and probabilities of the distribution determine the expected value.
#
# For example:
#
# If the distribution is symmetric, the expected value is at the center.
#
# If skewed, the expected value shifts towards the side with more probability weight.
#
#  Mathematical Link:
# For a discrete random variable:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑖
# 𝑥
# 𝑖
# ⋅
# 𝑃
# (
# 𝑥
# 𝑖
# )
# E(X)=
# i
# ∑
# ​
#  x
# i
# ​
#  ⋅P(x
# i
# ​
#  )
# For a continuous random variable:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# −
# ∞
# ∞
# 𝑥
# ⋅
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# E(X)=∫
# −∞
# ∞
# ​
#  x⋅f(x)dx
# Where:
#
# 𝑃
# (
# 𝑥
# 𝑖
# )
# P(x
# i
# ​
#  ) or
# 𝑓
# (
# 𝑥
# )
# f(x) comes from the probability distribution.
#
#  4. Expected Value Summarizes the Distribution in One Number
# While a distribution gives the full picture of all outcomes, the expected value gives a summary measure of where, on average, outcomes tend to be.
